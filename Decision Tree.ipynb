# %% [markdown]
# Input libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importing our train dataframe

# %%
traindata = pd.read_csv('income.train.csv')   # our full train dataframe

# %% [markdown]
# "totalentropy" is a function to calculate the entropy of an entire dataset

# %%
def totalentropy(dataset):
    ent = 0
    totalvalues = dataset.shape[0]
    sampleval = dataset[dataset.columns[-1]].value_counts()
    for i in range(len(sampleval.value_counts())):
        ent  = ent  - (sampleval[i]/totalvalues)* np.log2(sampleval[i]/totalvalues)

    return ent

# %% [markdown]
# "infogain" is a function to calculate the information gain of each feature in our dataset and store them in a 1-D array

# %%
def infogain (dataset, yesval, noval):
    gain = [0]*(len(dataset.columns)-1)
    I = [0]*(len(dataset.columns)-1)
    for c in range (len(dataset.columns)-1):
        H = [0]*len(dataset.groupby(dataset.columns[c]).label.count())
        totalvals = dataset.groupby(dataset.columns[c]).label.count()
        morevals = dataset.groupby([dataset.columns[c],dataset.columns[-1]]).label.count().unstack().groupby(dataset.columns[c])[yesval].sum().astype('Int32')
        lessvals = dataset.groupby([dataset.columns[c],dataset.columns[-1]]).label.count().unstack().groupby(dataset.columns[c])[noval].sum().astype('Int32')
        for i in range (len(dataset.groupby(dataset.columns[c]).label.count())):
            if (morevals[i]==totalvals[i] or lessvals[i]==totalvals[i]):
                H[i] = 0
            else: 
                H[i]  = H[i] - (morevals[i]/totalvals[i])* np.log2(morevals[i]/totalvals[i]) - (lessvals[i]/totalvals[i])* np.log2(lessvals[i]/totalvals[i])
        P = [0]*len(dataset.groupby(dataset.columns[c]).label.count())
        for i in range (len(dataset.groupby(dataset.columns[c]).label.count())):
            P[i] = totalvals[i]/dataset.shape[0]
        
        for j in range (len(dataset.groupby(dataset.columns[c]).label.count())):
            I[c] = I[c] + H[j]*P[j]
            
        gain[c] = totalentropy(dataset) - I[c]
    return gain

# %% [markdown]
# "id3" is the function that builds our decision tree using the ID3 algorithm in the form of a python dictionary

# %%
def id3(dataset, yesval, noval):
    
    
    # We calculate infogain for any given dataset
    gains = infogain(dataset, yesval, noval)
    
    
        
    # We find the feature with highest gain
    highestgainindex = np.where(gains == np.amax(gains))
    
    #if there only exist one feature with the max gain value we proceed normally
    if (len(highestgainindex[0])==1):
        index = highestgainindex[0][0]
        node = dataset.columns[index]
        
    #if there are more than one features with the max gain value we pick the first feature and eliminate the rest
    else:
       
       
        for i in range (len(highestgainindex[0])-1):
            dataset = dataset.drop(columns=dataset.columns[highestgainindex[0][len(highestgainindex[0])-1-i]])
        if (len(dataset.columns)>2):
            gains = infogain(dataset, yesval, noval)
            highestgainindex = np.where(gains == np.amax(gains))
            index = highestgainindex[0][0]
            node = dataset.columns[index]
            
        #if by eliminating the features with same info gain, our dataset is left with only one feature in total (with the excption of 'label')
        else:
            index = 0
            node = dataset.columns[index]
            

        
    
    
    tree = { node:{}}
    for i in range(len(dataset.groupby(dataset.columns[index]).label.count())):
        totalvals = dataset.groupby(dataset.columns[index]).label.count()
        morevals = dataset.groupby([dataset.columns[index],dataset.columns[-1]]).label.count().unstack().groupby(dataset.columns[index])[yesval].sum().astype('Int32')
        lessvals = dataset.groupby([dataset.columns[index],dataset.columns[-1]]).label.count().unstack().groupby(dataset.columns[index])[noval].sum().astype('Int32')

        if (morevals[i]==totalvals[i]):
            tree[node][dataset.groupby(dataset.columns[index]).label.count().index[i]] = yesval 
        elif (lessvals[i]==totalvals[i]):     
            tree[node][dataset.groupby(dataset.columns[index]).label.count().index[i]] =  noval 

            
        else:
            if ((len(dataset.columns)-1)==1):
                morevals = dataset.groupby([dataset.columns[index],dataset.columns[-1]]).label.count().unstack().groupby(dataset.columns[index])[yesval].sum().astype('Int32')
                lessvals = dataset.groupby([dataset.columns[index],dataset.columns[-1]]).label.count().unstack().groupby(dataset.columns[index])[noval].sum().astype('Int32')
                if (morevals[i]>lessvals[i]):
                    
                    tree[node][dataset.groupby(dataset.columns[index]).label.count().index[i]] =  yesval 
                else:
                   
                    tree[node][dataset.groupby(dataset.columns[index]).label.count().index[i]] =  noval 
                
            else:    
                isolateddata = dataset.groupby(dataset.columns[index])
                isolateddata = isolateddata.get_group(dataset.groupby(dataset.columns[index]).label.count().index[i])
                isolateddata = isolateddata.drop(columns=dataset.columns[index])
                if ((len(isolateddata.columns)-1)==1):
                    morevals = isolateddata.groupby([isolateddata.columns[index],isolateddata.columns[-1]]).label.count().unstack().groupby(isolateddata.columns[index])[yesval].sum().astype('Int32')
                    lessvals = isolateddata.groupby([isolateddata.columns[index],isolateddata.columns[-1]]).label.count().unstack().groupby(isolateddata.columns[index])[noval].sum().astype('Int32')
                    if (morevals[0]>lessvals[0]):
                        
                        tree[node][dataset.groupby(dataset.columns[index]).label.count().index[i]] =  yesval 
                    else:
                    
                        tree[node][dataset.groupby(dataset.columns[index]).label.count().index[i]] =  noval 
                      
                else:
        
                    branch = id3(isolateddata, yesval, noval)
                    tree[node][dataset.groupby(dataset.columns[index]).label.count().index[i]] = branch
    return tree

# %% [markdown]
# By defining the output variables "yesval" and "noval" we build a decision tree using the train dataframe

# %%
yes = ">50K"
no = "<=50K"

tree = id3(traindata, yes, no)

# %%
tree
# Out:
# {'relationship': {' Husband': {'education': {' 10th': {'occupation': {' Adm-clerical': '<=50K',
#       ' Craft-repair': {'workclass': {' Private': {'race': {' Asian-Pac-Islander': '<=50K',
#           ' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Exec-managerial': {'workclass': {' Local-gov': '<=50K',
#         ' Private': '<=50K',
#         ' Self-emp-not-inc': '<=50K',
#         ' State-gov': '>50K'}},
#       ' Farming-fishing': '<=50K',
#       ' Handlers-cleaners': '<=50K',
#       ' Machine-op-inspct': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Other-service': '<=50K',
#       ' Protective-serv': '<=50K',
#       ' Sales': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' Self-emp-inc': '<=50K',
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Tech-support': '>50K',
#       ' Transport-moving': {'workclass': {' Local-gov': '<=50K',
#         ' Private': {'race': {' Amer-Indian-Eskimo': '<=50K',
#           ' Black': '>50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Self-emp-not-inc': '<=50K'}}}},
#     ' 11th': {'occupation': {' Adm-clerical': '<=50K',
#       ' Craft-repair': {'workclass': {' Local-gov': '>50K',
#         ' Private': '<=50K',
#         ' Self-emp-inc': '>50K',
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Exec-managerial': '<=50K',
#       ' Farming-fishing': {'workclass': {' Private': '<=50K',
#         ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' State-gov': '<=50K'}},
#       ' Handlers-cleaners': {'race': {' Black': '<=50K',
#         ' White': {'workclass': {' Private': '<=50K'}}}},
#       ' Machine-op-inspct': {'race': {' Asian-Pac-Islander': '<=50K',
#         ' Black': '<=50K',
#         ' White': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Self-emp-not-inc': '<=50K'}}}},
#       ' Other-service': '<=50K',
#       ' Prof-specialty': '<=50K',
#       ' Protective-serv': '>50K',
#       ' Sales': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Transport-moving': {'workclass': {' Local-gov': '<=50K',
#         ' Private': {'race': {' Asian-Pac-Islander': '<=50K',
#           ' Black': '<=50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Self-emp-not-inc': '>50K'}}}},
#     ' 12th': {'occupation': {' Craft-repair': {'workclass': {' Local-gov': '<=50K',
#         ' Private': '<=50K',
#         ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#       ' Farming-fishing': '<=50K',
#       ' Handlers-cleaners': '>50K',
#       ' Machine-op-inspct': '<=50K',
#       ' Other-service': {'workclass': {' Local-gov': '>50K',
#         ' Private': '<=50K'}},
#       ' Tech-support': '<=50K',
#       ' Transport-moving': {'native-country': {' Cuba': '<=50K',
#         ' Jamaica': '<=50K',
#         ' Mexico': '<=50K',
#         ' United-States': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Self-emp-not-inc': '<=50K'}}}}}},
#     ' 1st-4th': {'occupation': {' Craft-repair': '<=50K',
#       ' Farming-fishing': {'workclass': {' Private': '<=50K'}},
#       ' Handlers-cleaners': '<=50K',
#       ' Machine-op-inspct': {'workclass': {' Private': '<=50K'}},
#       ' Other-service': '<=50K',
#       ' Transport-moving': '<=50K'}},
#     ' 5th-6th': {'occupation': {' Adm-clerical': '<=50K',
#       ' Craft-repair': {'workclass': {' Private': '<=50K',
#         ' Self-emp-not-inc': '>50K'}},
#       ' Exec-managerial': '>50K',
#       ' Farming-fishing': '<=50K',
#       ' Handlers-cleaners': '<=50K',
#       ' Machine-op-inspct': {'race': {' Asian-Pac-Islander': '<=50K',
#         ' White': {'workclass': {' Private': '<=50K'}}}},
#       ' Other-service': '<=50K',
#       ' Sales': {'workclass': {' Private': '<=50K',
#         ' Self-emp-inc': '>50K',
#         ' Self-emp-not-inc': '>50K'}},
#       ' Transport-moving': '<=50K'}},
#     ' 7th-8th': {'occupation': {' Craft-repair': {'race': {' Amer-Indian-Eskimo': '<=50K',
#         ' Asian-Pac-Islander': '<=50K',
#         ' Black': '>50K',
#         ' White': {'workclass': {' Private': '<=50K',
#           ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Self-emp-not-inc': '<=50K'}}}},
#       ' Exec-managerial': {'native-country': {' Greece': {'workclass': {' Self-emp-not-inc': '<=50K'}},
#         ' United-States': {'workclass': {' Self-emp-not-inc': '<=50K'}}}},
#       ' Farming-fishing': '<=50K',
#       ' Handlers-cleaners': '<=50K',
#       ' Machine-op-inspct': {'workclass': {' Private': {'native-country': {' Mexico': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' United-States': '<=50K'}},
#         ' Self-emp-inc': '>50K'}},
#       ' Other-service': '<=50K',
#       ' Prof-specialty': '<=50K',
#       ' Protective-serv': '<=50K',
#       ' Sales': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Transport-moving': {'workclass': {' Local-gov': '<=50K',
#         ' Private': {'race': {' Amer-Indian-Eskimo': '<=50K',
#           ' Black': '<=50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '>50K'}},
#         ' State-gov': '<=50K'}}}},
#     ' 9th': {'occupation': {' Adm-clerical': {'workclass': {' Private': '>50K',
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Craft-repair': {'workclass': {' Private': {'native-country': {' Mexico': '<=50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Self-emp-not-inc': '<=50K',
#         ' State-gov': '<=50K'}},
#       ' Exec-managerial': {'workclass': {' Private': '>50K',
#         ' Self-emp-inc': '<=50K'}},
#       ' Farming-fishing': '<=50K',
#       ' Handlers-cleaners': '<=50K',
#       ' Machine-op-inspct': '<=50K',
#       ' Other-service': '<=50K',
#       ' Prof-specialty': '<=50K',
#       ' Protective-serv': '<=50K',
#       ' Sales': '<=50K',
#       ' Tech-support': '<=50K',
#       ' Transport-moving': {'workclass': {' Local-gov': '<=50K',
#         ' Private': {'race': {' Black': '<=50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Self-emp-inc': '<=50K'}}}},
#     ' Assoc-acdm': {'occupation': {' Adm-clerical': {'workclass': {' Federal-gov': {'race': {' Black': '>50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Local-gov': '<=50K',
#         ' Private': {'native-country': {' Columbia': '<=50K',
#           ' India': '<=50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' State-gov': '>50K'}},
#       ' Craft-repair': {'workclass': {' Federal-gov': '>50K',
#         ' Private': {'native-country': {' Germany': '>50K',
#           ' Portugal': '<=50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Self-emp-not-inc': '<=50K',
#         ' State-gov': '<=50K'}},
#       ' Exec-managerial': {'workclass': {' Federal-gov': '<=50K',
#         ' Local-gov': '<=50K',
#         ' Private': {'marital-status': {' Married-civ-spouse': '>50K'}},
#         ' Self-emp-inc': '>50K'}},
#       ' Farming-fishing': '<=50K',
#       ' Handlers-cleaners': '<=50K',
#       ' Machine-op-inspct': {'workclass': {' Private': '>50K'}},
#       ' Other-service': '<=50K',
#       ' Prof-specialty': {'workclass': {' Federal-gov': '>50K',
#         ' Local-gov': {'native-country': {' Canada': '>50K',
#           ' United-States': '<=50K'}},
#         ' Private': {'race': {' Black': '<=50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Protective-serv': {'workclass': {' Local-gov': {'native-country': {' England': '<=50K',
#           ' Hong': '>50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Private': '>50K',
#         ' Self-emp-not-inc': '<=50K',
#         ' State-gov': '<=50K'}},
#       ' Sales': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '>50K'}},
#         ' Self-emp-inc': '>50K',
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Tech-support': {'workclass': {' Federal-gov': '<=50K',
#         ' Local-gov': '<=50K',
#         ' Private': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#       ' Transport-moving': {'workclass': {' Private': '<=50K',
#         ' Self-emp-not-inc': '>50K'}}}},
#     ' Assoc-voc': {'native-country': {' Canada': '<=50K',
#       ' England': '<=50K',
#       ' Germany': '>50K',
#       ' Greece': '<=50K',
#       ' Japan': '<=50K',
#       ' Mexico': '<=50K',
#       ' Philippines': '>50K',
#       ' Poland': '>50K',
#       ' Portugal': '>50K',
#       ' Puerto-Rico': '<=50K',
#       ' United-States': {'occupation': {' Adm-clerical': {'workclass': {' Private': '<=50K'}},
#         ' Craft-repair': {'workclass': {' Federal-gov': {'race': {' Asian-Pac-Islander': '>50K',
#             ' White': '<=50K'}},
#           ' Local-gov': '>50K',
#           ' Private': {'race': {' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#           ' Self-emp-inc': '<=50K',
#           ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' State-gov': '<=50K'}},
#         ' Exec-managerial': {'workclass': {' Local-gov': '>50K',
#           ' Private': {'race': {' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Self-emp-not-inc': '<=50K',
#           ' State-gov': '<=50K'}},
#         ' Farming-fishing': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Handlers-cleaners': {'race': {' Black': '<=50K',
#           ' White': {'workclass': {' Private': '<=50K'}}}},
#         ' Machine-op-inspct': {'race': {' Amer-Indian-Eskimo': '<=50K',
#           ' Asian-Pac-Islander': '>50K',
#           ' White': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' State-gov': '>50K'}}}},
#         ' Other-service': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' State-gov': '<=50K'}},
#         ' Prof-specialty': {'workclass': {' Local-gov': '<=50K',
#           ' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Self-emp-not-inc': {'race': {' Other': '<=50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}},
#         ' Protective-serv': {'workclass': {' Federal-gov': '<=50K',
#           ' Local-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Sales': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Self-emp-not-inc': '>50K'}},
#         ' Tech-support': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Self-emp-not-inc': '<=50K',
#           ' State-gov': '>50K'}},
#         ' Transport-moving': {'workclass': {' Private': '<=50K'}}}}}},
#     ' Bachelors': {'occupation': {' Adm-clerical': {'native-country': {' Canada': '<=50K',
#         ' Germany': '>50K',
#         ' India': '<=50K',
#         ' Iran': '>50K',
#         ' Italy': '<=50K',
#         ' Mexico': '<=50K',
#         ' Philippines': {'workclass': {' Federal-gov': '>50K',
#           ' Private': '<=50K'}},
#         ' United-States': {'workclass': {' Federal-gov': '>50K',
#           ' Local-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Private': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Self-emp-not-inc': '<=50K',
#           ' State-gov': {'race': {' Black': '<=50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}}}},
#         ' Vietnam': '<=50K'}},
#       ' Craft-repair': {'workclass': {' Local-gov': '<=50K',
#         ' Private': {'native-country': {' Canada': '<=50K',
#           ' Mexico': '<=50K',
#           ' South': '<=50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Self-emp-inc': '>50K',
#         ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#       ' Exec-managerial': {'native-country': {' Canada': '>50K',
#         ' Dominican-Republic': '<=50K',
#         ' England': '>50K',
#         ' France': '>50K',
#         ' Germany': {'workclass': {' Self-emp-inc': '>50K',
#           ' Self-emp-not-inc': '<=50K'}},
#         ' Greece': '>50K',
#         ' India': '>50K',
#         ' Iran': '>50K',
#         ' Italy': '>50K',
#         ' Japan': '>50K',
#         ' Philippines': '<=50K',
#         ' Puerto-Rico': {'workclass': {' Private': '<=50K',
#           ' Self-emp-not-inc': '>50K'}},
#         ' South': {'workclass': {' Private': '<=50K'}},
#         ' United-States': {'workclass': {' Federal-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Local-gov': {'race': {' Black': '>50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' Private': {'race': {' Black': {'marital-status': {' Married-civ-spouse': '>50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' State-gov': {'marital-status': {' Married-civ-spouse': '>50K'}}}}}},
#       ' Farming-fishing': {'workclass': {' Private': {'native-country': {' England': '<=50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Self-emp-inc': '>50K',
#         ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#       ' Handlers-cleaners': {'race': {' Asian-Pac-Islander': '<=50K',
#         ' Black': '>50K',
#         ' White': {'workclass': {' Local-gov': '>50K', ' Private': '<=50K'}}}},
#       ' Machine-op-inspct': {'race': {' Amer-Indian-Eskimo': '<=50K',
#         ' Black': '<=50K',
#         ' White': {'native-country': {' Poland': '>50K',
#           ' United-States': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}}}},
#       ' Other-service': {'native-country': {' China': '<=50K',
#         ' Cuba': '<=50K',
#         ' El-Salvador': '<=50K',
#         ' Philippines': '>50K',
#         ' South': '<=50K',
#         ' United-States': {'race': {' Asian-Pac-Islander': '>50K',
#           ' Black': {'workclass': {' Private': '<=50K'}},
#           ' White': '<=50K'}},
#         ' Vietnam': '<=50K'}},
#       ' Prof-specialty': {'native-country': {' Canada': '>50K',
#         ' China': '>50K',
#         ' Ecuador': '<=50K',
#         ' El-Salvador': '<=50K',
#         ' Germany': '<=50K',
#         ' India': {'workclass': {' Local-gov': '<=50K', ' State-gov': '>50K'}},
#         ' Iran': {'workclass': {' Federal-gov': '<=50K',
#           ' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Italy': '>50K',
#         ' Japan': '<=50K',
#         ' Nicaragua': '<=50K',
#         ' Peru': '>50K',
#         ' Puerto-Rico': '>50K',
#         ' South': '<=50K',
#         ' United-States': {'workclass': {' Federal-gov': {'race': {' Asian-Pac-Islander': '>50K',
#             ' Black': '>50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' Local-gov': {'race': {' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' Private': {'race': {' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Self-emp-not-inc': {'race': {' Black': '>50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' State-gov': {'marital-status': {' Married-civ-spouse': '>50K'}}}}}},
#       ' Protective-serv': {'workclass': {' Federal-gov': {'race': {' Black': '>50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Local-gov': {'race': {' Black': '>50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Private': {'race': {' Black': '<=50K', ' White': '>50K'}},
#         ' State-gov': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#       ' Sales': {'native-country': {' Canada': '>50K',
#         ' China': '>50K',
#         ' India': '<=50K',
#         ' Iran': '>50K',
#         ' Japan': '<=50K',
#         ' Poland': '<=50K',
#         ' Puerto-Rico': '<=50K',
#         ' South': '<=50K',
#         ' United-States': {'workclass': {' Federal-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Local-gov': '>50K',
#           ' Private': {'race': {' Black': '>50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Vietnam': '<=50K'}},
#       ' Tech-support': {'workclass': {' Federal-gov': {'race': {' Black': '>50K',
#           ' White': '<=50K'}},
#         ' Local-gov': '>50K',
#         ' Private': {'marital-status': {' Married-civ-spouse': '>50K'}},
#         ' Self-emp-inc': '<=50K',
#         ' State-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#       ' Transport-moving': {'native-country': {' Canada': '>50K',
#         ' United-States': {'workclass': {' Private': '<=50K'}}}}}},
#     ' Doctorate': {'native-country': {' Canada': {'workclass': {' Private': '<=50K',
#         ' Self-emp-inc': '>50K'}},
#       ' China': '>50K',
#       ' Columbia': '>50K',
#       ' Cuba': '>50K',
#       ' El-Salvador': '>50K',
#       ' Germany': '>50K',
#       ' India': '<=50K',
#       ' Iran': '>50K',
#       ' Taiwan': {'workclass': {' Private': '>50K',
#         ' State-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#       ' United-States': {'workclass': {' Federal-gov': '>50K',
#         ' Local-gov': '>50K',
#         ' Private': {'occupation': {' Adm-clerical': '>50K',
#           ' Exec-managerial': '>50K',
#           ' Prof-specialty': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Self-emp-inc': '>50K',
#         ' Self-emp-not-inc': {'occupation': {' Craft-repair': '<=50K',
#           ' Exec-managerial': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Prof-specialty': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' State-gov': '>50K'}}}},
#     ' HS-grad': {'occupation': {' Adm-clerical': {'race': {' Amer-Indian-Eskimo': '>50K',
#         ' Asian-Pac-Islander': '<=50K',
#         ' Black': {'workclass': {' Federal-gov': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Local-gov': '<=50K',
#           ' Private': '<=50K',
#           ' State-gov': '>50K'}},
#         ' Other': '<=50K',
#         ' White': {'native-country': {' Germany': '>50K',
#           ' Mexico': '<=50K',
#           ' United-States': {'workclass': {' Federal-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' Private': {'marital-status': {' Married-AF-spouse': '<=50K',
#               ' Married-civ-spouse': '<=50K'}},
#             ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' State-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}}}},
#       ' Craft-repair': {'native-country': {' Cuba': '>50K',
#         ' Ecuador': '>50K',
#         ' El-Salvador': '<=50K',
#         ' England': '<=50K',
#         ' Germany': '<=50K',
#         ' Greece': '<=50K',
#         ' Italy': '>50K',
#         ' Laos': '<=50K',
#         ' Mexico': {'workclass': {' Private': '<=50K'}},
#         ' Peru': '<=50K',
#         ' Poland': '<=50K',
#         ' South': '<=50K',
#         ' United-States': {'workclass': {' Federal-gov': '>50K',
#           ' Local-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Private': {'race': {' Amer-Indian-Eskimo': '<=50K',
#             ' Asian-Pac-Islander': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' Other': '<=50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#           ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Self-emp-not-inc': {'marital-status': {' Married-AF-spouse': '<=50K',
#             ' Married-civ-spouse': {'race': {' White': '<=50K'}}}},
#           ' State-gov': {'race': {' Black': '>50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}}}},
#       ' Exec-managerial': {'native-country': {' Canada': '>50K',
#         ' China': '<=50K',
#         ' Columbia': '<=50K',
#         ' Greece': '<=50K',
#         ' Hungary': '<=50K',
#         ' Japan': '>50K',
#         ' Taiwan': '>50K',
#         ' United-States': {'workclass': {' Federal-gov': '>50K',
#           ' Local-gov': {'race': {' Amer-Indian-Eskimo': '<=50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#           ' Private': {'race': {' Black': '<=50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' Self-emp-inc': {'race': {' Asian-Pac-Islander': '>50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' Self-emp-not-inc': {'race': {' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#           ' State-gov': '<=50K'}}}},
#       ' Farming-fishing': {'native-country': {' Cambodia': '>50K',
#         ' Italy': '<=50K',
#         ' Mexico': '<=50K',
#         ' United-States': {'workclass': {' Local-gov': '<=50K',
#           ' Private': {'race': {' Amer-Indian-Eskimo': '<=50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#           ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Self-emp-not-inc': {'race': {' Asian-Pac-Islander': '<=50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}}}},
#       ' Handlers-cleaners': {'workclass': {' Local-gov': '<=50K',
#         ' Private': {'race': {' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Self-emp-inc': '<=50K',
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Machine-op-inspct': {'native-country': {' Canada': '<=50K',
#         ' Cuba': '>50K',
#         ' England': {'workclass': {' Private': '<=50K'}},
#         ' Haiti': '<=50K',
#         ' Ireland': {'workclass': {' Private': '<=50K'}},
#         ' Italy': '<=50K',
#         ' Mexico': '<=50K',
#         ' Portugal': '<=50K',
#         ' South': '<=50K',
#         ' United-States': {'race': {' Amer-Indian-Eskimo': '<=50K',
#           ' Black': {'workclass': {' Private': '<=50K'}},
#           ' White': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' Self-emp-not-inc': '<=50K'}}}}}},
#       ' Other-service': {'native-country': {' Canada': '>50K',
#         ' China': '<=50K',
#         ' England': '<=50K',
#         ' Germany': '<=50K',
#         ' Ireland': '<=50K',
#         ' Japan': '<=50K',
#         ' Mexico': {'workclass': {' Private': '<=50K'}},
#         ' Thailand': '<=50K',
#         ' United-States': {'race': {' Amer-Indian-Eskimo': '<=50K',
#           ' Black': '<=50K',
#           ' Other': '<=50K',
#           ' White': {'workclass': {' Federal-gov': '<=50K',
#             ' Local-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' State-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}},
#         ' Yugoslavia': {'workclass': {' Private': '<=50K'}}}},
#       ' Prof-specialty': {'workclass': {' Federal-gov': '>50K',
#         ' Local-gov': '>50K',
#         ' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' Self-emp-inc': '>50K',
#         ' Self-emp-not-inc': '>50K',
#         ' State-gov': '>50K'}},
#       ' Protective-serv': {'race': {' Amer-Indian-Eskimo': '>50K',
#         ' Asian-Pac-Islander': '>50K',
#         ' Black': '<=50K',
#         ' White': {'workclass': {' Local-gov': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Self-emp-not-inc': '<=50K',
#           ' State-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}},
#       ' Sales': {'native-country': {' Canada': '>50K',
#         ' Columbia': '<=50K',
#         ' Cuba': '<=50K',
#         ' Ecuador': '<=50K',
#         ' El-Salvador': '>50K',
#         ' England': '>50K',
#         ' Germany': '<=50K',
#         ' Greece': '<=50K',
#         ' Mexico': '<=50K',
#         ' South': {'workclass': {' Self-emp-not-inc': '<=50K'}},
#         ' United-States': {'workclass': {' Private': {'race': {' Amer-Indian-Eskimo': '<=50K',
#             ' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' Other': '<=50K',
#             ' White': {'sex': {' Female': '<=50K', ' Male': '<=50K'}}}},
#           ' Self-emp-inc': {'race': {' Black': '<=50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' Self-emp-not-inc': {'race': {' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#           ' State-gov': '<=50K'}}}},
#       ' Tech-support': {'workclass': {' Federal-gov': '<=50K',
#         ' Private': {'race': {' Asian-Pac-Islander': '>50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Self-emp-not-inc': '<=50K',
#         ' State-gov': '<=50K'}},
#       ' Transport-moving': {'workclass': {' Federal-gov': {'race': {' Amer-Indian-Eskimo': '<=50K',
#           ' Black': '>50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Local-gov': '<=50K',
#         ' Private': {'race': {' Amer-Indian-Eskimo': '<=50K',
#           ' Asian-Pac-Islander': '<=50K',
#           ' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Other': '<=50K',
#           ' White': {'native-country': {' Canada': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' Italy': '>50K',
#             ' Puerto-Rico': '<=50K',
#             ' United-States': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}},
#         ' Self-emp-inc': '<=50K',
#         ' Self-emp-not-inc': {'native-country': {' Mexico': '>50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' State-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}},
#     ' Masters': {'occupation': {' Adm-clerical': {'workclass': {' Federal-gov': '>50K',
#         ' Local-gov': '>50K',
#         ' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' State-gov': '<=50K'}},
#       ' Craft-repair': {'workclass': {' Private': '>50K',
#         ' Self-emp-inc': '<=50K',
#         ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#       ' Exec-managerial': {'workclass': {' Federal-gov': {'native-country': {' England': '>50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Local-gov': {'marital-status': {' Married-civ-spouse': '>50K'}},
#         ' Private': {'native-country': {' Cuba': '>50K',
#           ' El-Salvador': '>50K',
#           ' Germany': '>50K',
#           ' Greece': '>50K',
#           ' India': '<=50K',
#           ' Japan': '>50K',
#           ' Taiwan': '>50K',
#           ' United-States': {'race': {' Asian-Pac-Islander': '>50K',
#             ' Black': '>50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}}}},
#         ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '>50K'}},
#         ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '>50K'}},
#         ' State-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#       ' Farming-fishing': {'workclass': {' Self-emp-not-inc': '<=50K'}},
#       ' Machine-op-inspct': '<=50K',
#       ' Other-service': '<=50K',
#       ' Prof-specialty': {'native-country': {' Canada': '<=50K',
#         ' China': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' State-gov': '<=50K'}},
#         ' England': {'workclass': {' Private': '>50K'}},
#         ' Greece': '<=50K',
#         ' India': '>50K',
#         ' Iran': '>50K',
#         ' Poland': '>50K',
#         ' Taiwan': {'workclass': {' Private': '>50K', ' State-gov': '<=50K'}},
#         ' United-States': {'race': {' Black': {'workclass': {' Local-gov': '>50K',
#             ' Private': '<=50K',
#             ' State-gov': '>50K'}},
#           ' Other': '<=50K',
#           ' White': {'workclass': {' Federal-gov': '>50K',
#             ' Local-gov': {'marital-status': {' Married-civ-spouse': '>50K'}},
#             ' Private': {'marital-status': {' Married-civ-spouse': '>50K'}},
#             ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' State-gov': {'marital-status': {' Married-civ-spouse': '>50K'}}}}}}}},
#       ' Protective-serv': {'workclass': {' Local-gov': '>50K',
#         ' Private': '>50K',
#         ' State-gov': '<=50K'}},
#       ' Sales': {'native-country': {' India': '<=50K',
#         ' Mexico': '>50K',
#         ' United-States': {'workclass': {' Federal-gov': '>50K',
#           ' Private': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Self-emp-inc': '>50K',
#           ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '>50K'}}}}}},
#       ' Tech-support': {'workclass': {' Federal-gov': '>50K',
#         ' Private': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#       ' Transport-moving': {'native-country': {' Poland': '<=50K',
#         ' United-States': '>50K'}}}},
#     ' Preschool': '<=50K',
#     ' Prof-school': {'occupation': {' Adm-clerical': '<=50K',
#       ' Craft-repair': '>50K',
#       ' Exec-managerial': {'workclass': {' Private': '<=50K',
#         ' Self-emp-inc': '<=50K',
#         ' State-gov': '>50K'}},
#       ' Farming-fishing': {'workclass': {' Self-emp-not-inc': '<=50K'}},
#       ' Prof-specialty': {'workclass': {' Federal-gov': {'native-country': {' Columbia': '<=50K',
#           ' India': '>50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Local-gov': '>50K',
#         ' Private': {'native-country': {' Haiti': '<=50K',
#           ' India': '>50K',
#           ' Philippines': '<=50K',
#           ' Taiwan': '>50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Self-emp-inc': '>50K',
#         ' Self-emp-not-inc': {'race': {' Amer-Indian-Eskimo': '>50K',
#           ' Asian-Pac-Islander': '>50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' State-gov': '>50K'}},
#       ' Protective-serv': '>50K',
#       ' Sales': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Tech-support': '>50K',
#       ' Transport-moving': '>50K'}},
#     ' Some-college': {'occupation': {' Adm-clerical': {'workclass': {' Federal-gov': '>50K',
#         ' Local-gov': {'native-country': {' Canada': '>50K',
#           ' United-States': '<=50K'}},
#         ' Private': {'race': {' Black': '>50K',
#           ' White': {'native-country': {' Mexico': '<=50K',
#             ' United-States': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}},
#         ' State-gov': '<=50K'}},
#       ' Craft-repair': {'native-country': {' Canada': '<=50K',
#         ' El-Salvador': '<=50K',
#         ' Germany': '>50K',
#         ' Greece': '<=50K',
#         ' Italy': '<=50K',
#         ' Jamaica': '>50K',
#         ' Mexico': '<=50K',
#         ' Poland': '<=50K',
#         ' South': '<=50K',
#         ' United-States': {'workclass': {' Federal-gov': '<=50K',
#           ' Local-gov': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Private': {'race': {' Amer-Indian-Eskimo': '>50K',
#             ' Asian-Pac-Islander': '>50K',
#             ' Black': {'marital-status': {' Married-civ-spouse': '>50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#           ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Self-emp-not-inc': {'race': {' Amer-Indian-Eskimo': {'marital-status': {' Married-civ-spouse': '>50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#           ' State-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}},
#       ' Exec-managerial': {'workclass': {' Federal-gov': '>50K',
#         ' Local-gov': {'race': {' Black': '>50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Private': {'race': {' Asian-Pac-Islander': '<=50K',
#           ' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' White': {'native-country': {' Jamaica': '>50K',
#             ' United-States': {'marital-status': {' Married-civ-spouse': '>50K'}}}}}},
#         ' Self-emp-inc': {'native-country': {' Taiwan': '<=50K',
#           ' Thailand': '>50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Self-emp-not-inc': {'race': {' Amer-Indian-Eskimo': '<=50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' State-gov': '<=50K'}},
#       ' Farming-fishing': {'workclass': {' Local-gov': '<=50K',
#         ' Private': {'race': {' Other': '<=50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' State-gov': '<=50K'}},
#       ' Handlers-cleaners': {'workclass': {' Federal-gov': '>50K',
#         ' Local-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' Private': {'native-country': {' Canada': '>50K',
#           ' Mexico': '<=50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}},
#       ' Machine-op-inspct': {'workclass': {' Federal-gov': '<=50K',
#         ' Private': {'race': {' Asian-Pac-Islander': '>50K',
#           ' Black': '<=50K',
#           ' White': {'native-country': {' Mexico': '<=50K',
#             ' United-States': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}},
#         ' Self-emp-inc': '<=50K',
#         ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '>50K'}},
#         ' State-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#       ' Other-service': {'workclass': {' Federal-gov': '<=50K',
#         ' Local-gov': {'race': {' Asian-Pac-Islander': '<=50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Private': {'race': {' Asian-Pac-Islander': '<=50K',
#           ' Black': '<=50K',
#           ' Other': '<=50K',
#           ' White': {'native-country': {' Mexico': '<=50K',
#             ' United-States': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}},
#         ' Self-emp-not-inc': '>50K',
#         ' State-gov': '<=50K'}},
#       ' Prof-specialty': {'race': {' Amer-Indian-Eskimo': '<=50K',
#         ' Asian-Pac-Islander': '>50K',
#         ' Black': '>50K',
#         ' Other': '>50K',
#         ' White': {'workclass': {' Federal-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Local-gov': '<=50K',
#           ' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Self-emp-inc': '<=50K',
#           ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' State-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}},
#       ' Protective-serv': {'workclass': {' Federal-gov': '>50K',
#         ' Local-gov': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' Private': {'race': {' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' White': '<=50K'}},
#         ' State-gov': '<=50K'}},
#       ' Sales': {'native-country': {' El-Salvador': '<=50K',
#         ' Germany': '<=50K',
#         ' Philippines': '<=50K',
#         ' Taiwan': '<=50K',
#         ' United-States': {'workclass': {' Local-gov': '<=50K',
#           ' Private': {'race': {' Asian-Pac-Islander': '>50K',
#             ' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Self-emp-not-inc': {'race': {' Black': '>50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}}}},
#       ' Tech-support': {'native-country': {' Guatemala': '>50K',
#         ' Jamaica': '>50K',
#         ' Poland': '<=50K',
#         ' United-States': {'race': {' Asian-Pac-Islander': '>50K',
#           ' Black': '<=50K',
#           ' White': {'workclass': {' Federal-gov': {'marital-status': {' Married-civ-spouse': '>50K'}},
#             ' Local-gov': '>50K',
#             ' Private': {'marital-status': {' Married-civ-spouse': '>50K'}},
#             ' Self-emp-not-inc': '>50K'}}}}}},
#       ' Transport-moving': {'workclass': {' Local-gov': '<=50K',
#         ' Private': {'native-country': {' Canada': '>50K',
#           ' El-Salvador': '<=50K',
#           ' United-States': {'race': {' Black': '<=50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}},
#         ' Self-emp-inc': '>50K',
#         ' Self-emp-not-inc': '<=50K',
#         ' State-gov': '<=50K'}}}}}},
#   ' Not-in-family': {'education': {' 10th': {'occupation': {' Adm-clerical': '<=50K',
#       ' Craft-repair': '<=50K',
#       ' Farming-fishing': '<=50K',
#       ' Handlers-cleaners': '<=50K',
#       ' Machine-op-inspct': '<=50K',
#       ' Other-service': '<=50K',
#       ' Priv-house-serv': '<=50K',
#       ' Prof-specialty': {'workclass': {' Private': '>50K',
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Sales': '<=50K',
#       ' Transport-moving': {'workclass': {' Local-gov': '<=50K',
#         ' Private': '<=50K',
#         ' Self-emp-inc': '>50K',
#         ' Self-emp-not-inc': '<=50K'}}}},
#     ' 11th': {'occupation': {' Adm-clerical': '<=50K',
#       ' Craft-repair': '<=50K',
#       ' Exec-managerial': '<=50K',
#       ' Farming-fishing': '<=50K',
#       ' Handlers-cleaners': '<=50K',
#       ' Machine-op-inspct': '<=50K',
#       ' Other-service': '<=50K',
#       ' Sales': {'marital-status': {' Divorced': {'workclass': {' Private': {'race': {' White': '<=50K'}},
#           ' Self-emp-inc': '<=50K'}},
#         ' Never-married': '<=50K'}},
#       ' Tech-support': '<=50K',
#       ' Transport-moving': {'marital-status': {' Divorced': '<=50K',
#         ' Never-married': {'race': {' Black': '<=50K',
#           ' White': {'workclass': {' Private': '<=50K'}}}},
#         ' Separated': '<=50K'}}}},
#     ' 12th': {'occupation': {' Adm-clerical': '<=50K',
#       ' Craft-repair': {'marital-status': {' Divorced': '>50K',
#         ' Never-married': '<=50K'}},
#       ' Exec-managerial': {'workclass': {' Private': '<=50K',
#         ' State-gov': {'marital-status': {' Never-married': '<=50K'}}}},
#       ' Handlers-cleaners': '<=50K',
#       ' Machine-op-inspct': '<=50K',
#       ' Other-service': '<=50K',
#       ' Sales': '<=50K'}},
#     ' 1st-4th': '<=50K',
#     ' 5th-6th': '<=50K',
#     ' 7th-8th': {'marital-status': {' Divorced': '<=50K',
#       ' Married-spouse-absent': {'workclass': {' Private': '<=50K',
#         ' Self-emp-not-inc': '>50K'}},
#       ' Never-married': {'occupation': {' Craft-repair': '<=50K',
#         ' Handlers-cleaners': '<=50K',
#         ' Machine-op-inspct': '<=50K',
#         ' Other-service': {'native-country': {' Mexico': '<=50K',
#           ' United-States': '>50K'}},
#         ' Transport-moving': {'race': {' Amer-Indian-Eskimo': '<=50K',
#           ' White': '>50K'}}}},
#       ' Separated': '<=50K',
#       ' Widowed': '<=50K'}},
#     ' 9th': {'native-country': {' Canada': '<=50K',
#       ' China': '<=50K',
#       ' Dominican-Republic': '<=50K',
#       ' Jamaica': '<=50K',
#       ' Mexico': '<=50K',
#       ' Puerto-Rico': '>50K',
#       ' United-States': '<=50K'}},
#     ' Assoc-acdm': {'occupation': {' Adm-clerical': {'race': {' Asian-Pac-Islander': {'marital-status': {' Divorced': '<=50K',
#           ' Never-married': '>50K'}},
#         ' Black': '<=50K',
#         ' Other': '<=50K',
#         ' White': '<=50K'}},
#       ' Craft-repair': {'marital-status': {' Divorced': '<=50K',
#         ' Married-civ-spouse': '>50K',
#         ' Married-spouse-absent': '<=50K',
#         ' Never-married': '<=50K',
#         ' Separated': '<=50K'}},
#       ' Exec-managerial': {'marital-status': {' Divorced': {'sex': {' Female': '<=50K',
#           ' Male': {'workclass': {' Private': '>50K',
#             ' Self-emp-not-inc': '<=50K'}}}},
#         ' Never-married': '<=50K',
#         ' Separated': '<=50K'}},
#       ' Farming-fishing': '<=50K',
#       ' Machine-op-inspct': {'marital-status': {' Divorced': '<=50K',
#         ' Never-married': '>50K'}},
#       ' Other-service': '<=50K',
#       ' Priv-house-serv': '<=50K',
#       ' Prof-specialty': {'workclass': {' Federal-gov': '>50K',
#         ' Local-gov': '<=50K',
#         ' Private': '<=50K',
#         ' Self-emp-not-inc': '<=50K',
#         ' State-gov': '<=50K'}},
#       ' Protective-serv': {'sex': {' Female': '>50K', ' Male': '<=50K'}},
#       ' Sales': '<=50K',
#       ' Tech-support': '<=50K',
#       ' Transport-moving': '<=50K'}},
#     ' Assoc-voc': {'occupation': {' Adm-clerical': {'sex': {' Female': '<=50K',
#         ' Male': {'marital-status': {' Never-married': {'workclass': {' Private': '<=50K'}},
#           ' Separated': '<=50K',
#           ' Widowed': '<=50K'}}}},
#       ' Craft-repair': '<=50K',
#       ' Exec-managerial': '<=50K',
#       ' Farming-fishing': '<=50K',
#       ' Handlers-cleaners': '<=50K',
#       ' Machine-op-inspct': '<=50K',
#       ' Other-service': '<=50K',
#       ' Prof-specialty': {'workclass': {' Local-gov': '<=50K',
#         ' Private': {'marital-status': {' Divorced': {'sex': {' Female': '>50K',
#             ' Male': '<=50K'}},
#           ' Never-married': {'sex': {' Female': {'native-country': {' Canada': '<=50K',
#               ' United-States': '<=50K'}},
#             ' Male': '<=50K'}},
#           ' Widowed': '<=50K'}},
#         ' Self-emp-not-inc': '<=50K',
#         ' State-gov': '>50K'}},
#       ' Protective-serv': {'workclass': {' Local-gov': {'marital-status': {' Never-married': '<=50K'}},
#         ' Private': '<=50K'}},
#       ' Sales': {'workclass': {' Private': {'sex': {' Female': '<=50K',
#           ' Male': {'marital-status': {' Divorced': {'race': {' White': '<=50K'}},
#             ' Never-married': {'race': {' White': '<=50K'}}}}}},
#         ' Self-emp-inc': '<=50K'}},
#       ' Tech-support': {'workclass': {' Federal-gov': '<=50K',
#         ' Local-gov': '<=50K',
#         ' Private': '<=50K',
#         ' State-gov': {'marital-status': {' Divorced': '>50K',
#           ' Never-married': '<=50K'}}}},
#       ' Transport-moving': '<=50K'}},
#     ' Bachelors': {'occupation': {' Adm-clerical': {'marital-status': {' Divorced': {'workclass': {' Local-gov': '>50K',
#           ' Private': {'race': {' Black': '<=50K',
#             ' White': {'sex': {' Female': '<=50K', ' Male': '<=50K'}}}}}},
#         ' Married-spouse-absent': '<=50K',
#         ' Never-married': {'workclass': {' Federal-gov': '<=50K',
#           ' Local-gov': '<=50K',
#           ' Private': '<=50K',
#           ' Self-emp-not-inc': '<=50K',
#           ' State-gov': {'sex': {' Female': {'race': {' Black': '<=50K',
#               ' White': '<=50K'}},
#             ' Male': '<=50K'}}}},
#         ' Widowed': '<=50K'}},
#       ' Craft-repair': {'marital-status': {' Divorced': '<=50K',
#         ' Never-married': {'sex': {' Female': '<=50K',
#           ' Male': {'workclass': {' Private': '<=50K',
#             ' State-gov': '<=50K'}}}},
#         ' Separated': '<=50K'}},
#       ' Exec-managerial': {'marital-status': {' Divorced': {'workclass': {' Federal-gov': {'race': {' White': '>50K'}},
#           ' Private': {'race': {' Amer-Indian-Eskimo': '<=50K',
#             ' Black': '>50K',
#             ' White': {'sex': {' Female': '<=50K', ' Male': '>50K'}}}},
#           ' Self-emp-inc': {'race': {' White': '<=50K'}},
#           ' Self-emp-not-inc': '<=50K',
#           ' State-gov': {'sex': {' Female': {'race': {' White': '<=50K'}},
#             ' Male': '<=50K'}}}},
#         ' Married-spouse-absent': {'race': {' Black': '>50K',
#           ' White': '<=50K'}},
#         ' Never-married': {'workclass': {' Federal-gov': {'race': {' Black': '<=50K',
#             ' White': '<=50K'}},
#           ' Local-gov': '<=50K',
#           ' Private': {'native-country': {' Canada': '<=50K',
#             ' Philippines': '<=50K',
#             ' Poland': '<=50K',
#             ' United-States': {'race': {' Black': '<=50K',
#               ' White': '<=50K'}}}},
#           ' Self-emp-not-inc': {'race': {' Black': '>50K',
#             ' White': {'sex': {' Male': '<=50K'}}}},
#           ' State-gov': '<=50K'}},
#         ' Separated': {'sex': {' Female': '<=50K', ' Male': '>50K'}},
#         ' Widowed': '>50K'}},
#       ' Farming-fishing': '<=50K',
#       ' Handlers-cleaners': '<=50K',
#       ' Machine-op-inspct': '<=50K',
#       ' Other-service': {'marital-status': {' Divorced': '<=50K',
#         ' Married-spouse-absent': '<=50K',
#         ' Never-married': {'race': {' Asian-Pac-Islander': '<=50K',
#           ' Black': '<=50K',
#           ' White': {'workclass': {' Local-gov': '<=50K',
#             ' Private': '<=50K'}}}},
#         ' Separated': '<=50K',
#         ' Widowed': '<=50K'}},
#       ' Priv-house-serv': '<=50K',
#       ' Prof-specialty': {'native-country': {' Cambodia': '>50K',
#         ' Canada': '<=50K',
#         ' Germany': '<=50K',
#         ' Iran': '<=50K',
#         ' Japan': '<=50K',
#         ' Outlying-US(Guam-USVI-etc)': '<=50K',
#         ' Philippines': '>50K',
#         ' Puerto-Rico': '<=50K',
#         ' United-States': {'workclass': {' Federal-gov': {'race': {' Amer-Indian-Eskimo': '<=50K',
#             ' Asian-Pac-Islander': '<=50K',
#             ' Other': '<=50K',
#             ' White': {'marital-status': {' Divorced': '<=50K',
#               ' Never-married': '<=50K'}}}},
#           ' Local-gov': {'marital-status': {' Divorced': '<=50K',
#             ' Married-spouse-absent': {'sex': {' Female': '<=50K',
#               ' Male': '<=50K'}},
#             ' Never-married': {'sex': {' Female': '<=50K', ' Male': '<=50K'}},
#             ' Separated': {'sex': {' Female': '<=50K', ' Male': '>50K'}},
#             ' Widowed': '<=50K'}},
#           ' Private': {'marital-status': {' Divorced': {'race': {' Black': '<=50K',
#               ' White': '<=50K'}},
#             ' Married-spouse-absent': '<=50K',
#             ' Never-married': {'sex': {' Female': '<=50K', ' Male': '<=50K'}},
#             ' Widowed': '>50K'}},
#           ' Self-emp-inc': '<=50K',
#           ' Self-emp-not-inc': {'marital-status': {' Divorced': '>50K',
#             ' Married-spouse-absent': '<=50K',
#             ' Never-married': '<=50K'}},
#           ' State-gov': '<=50K'}}}},
#       ' Protective-serv': {'workclass': {' Federal-gov': '>50K',
#         ' Local-gov': {'marital-status': {' Divorced': {'race': {' White': '<=50K'}},
#           ' Never-married': '<=50K'}},
#         ' Private': '<=50K',
# ...
#           ' Separated': {'sex': {' Female': {'race': {' White': '<=50K'}},
#             ' Male': '<=50K'}},
#           ' Widowed': '<=50K'}},
#         ' Sales': {'marital-status': {' Divorced': {'sex': {' Female': '<=50K',
#             ' Male': {'race': {' Black': '<=50K', ' White': '>50K'}}}},
#           ' Never-married': {'sex': {' Female': {'race': {' White': '<=50K'}},
#             ' Male': '<=50K'}},
#           ' Separated': '<=50K',
#           ' Widowed': '<=50K'}},
#         ' Tech-support': {'marital-status': {' Divorced': '>50K',
#           ' Never-married': '<=50K'}},
#         ' Transport-moving': '<=50K'}},
#       ' Self-emp-inc': '>50K',
#       ' Self-emp-not-inc': {'occupation': {' Farming-fishing': '<=50K',
#         ' Other-service': '>50K',
#         ' Prof-specialty': '>50K',
#         ' Sales': '>50K'}},
#       ' State-gov': {'race': {' Asian-Pac-Islander': '>50K',
#         ' White': '<=50K'}}}},
#     ' Doctorate': {'marital-status': {' Divorced': {'occupation': {' Prof-specialty': {'workclass': {' Private': '<=50K'}},
#         ' Sales': '>50K'}},
#       ' Married-spouse-absent': '>50K',
#       ' Widowed': '>50K'}},
#     ' HS-grad': {'occupation': {' Adm-clerical': {'workclass': {' Federal-gov': '<=50K',
#         ' Local-gov': '<=50K',
#         ' Private': '<=50K',
#         ' State-gov': {'marital-status': {' Divorced': {'sex': {' Female': '<=50K'}},
#           ' Never-married': '<=50K',
#           ' Separated': '<=50K'}}}},
#       ' Craft-repair': {'workclass': {' Federal-gov': '<=50K',
#         ' Local-gov': '<=50K',
#         ' Private': {'marital-status': {' Divorced': '<=50K',
#           ' Married-spouse-absent': '<=50K',
#           ' Never-married': {'native-country': {' Mexico': '<=50K',
#             ' United-States': {'sex': {' Female': '<=50K', ' Male': '<=50K'}},
#             ' Vietnam': '<=50K'}},
#           ' Separated': '<=50K',
#           ' Widowed': '<=50K'}},
#         ' Self-emp-not-inc': {'marital-status': {' Divorced': '>50K',
#           ' Separated': '<=50K'}},
#         ' State-gov': '<=50K'}},
#       ' Exec-managerial': {'race': {' Amer-Indian-Eskimo': '<=50K',
#         ' Asian-Pac-Islander': '<=50K',
#         ' Black': {'marital-status': {' Divorced': '>50K',
#           ' Never-married': '<=50K',
#           ' Separated': '<=50K',
#           ' Widowed': '<=50K'}},
#         ' White': '<=50K'}},
#       ' Farming-fishing': '<=50K',
#       ' Handlers-cleaners': '<=50K',
#       ' Machine-op-inspct': '<=50K',
#       ' Other-service': {'native-country': {' China': '<=50K',
#         ' Dominican-Republic': '<=50K',
#         ' El-Salvador': '<=50K',
#         ' Honduras': '<=50K',
#         ' India': {'workclass': {' Private': '>50K',
#           ' Self-emp-inc': '<=50K'}},
#         ' Jamaica': '<=50K',
#         ' Japan': '<=50K',
#         ' Mexico': '<=50K',
#         ' Puerto-Rico': '<=50K',
#         ' United-States': '<=50K'}},
#       ' Priv-house-serv': '<=50K',
#       ' Prof-specialty': {'workclass': {' Local-gov': '<=50K',
#         ' Private': '<=50K',
#         ' Self-emp-not-inc': '>50K'}},
#       ' Protective-serv': '<=50K',
#       ' Sales': {'workclass': {' Federal-gov': '<=50K',
#         ' Private': {'marital-status': {' Divorced': {'race': {' Amer-Indian-Eskimo': '<=50K',
#             ' Black': '<=50K',
#             ' White': {'sex': {' Female': '<=50K'}}}},
#           ' Married-spouse-absent': '<=50K',
#           ' Never-married': {'sex': {' Female': '<=50K',
#             ' Male': {'race': {' Black': '<=50K', ' White': '>50K'}}}},
#           ' Separated': '<=50K',
#           ' Widowed': '<=50K'}},
#         ' Self-emp-inc': {'sex': {' Female': '>50K', ' Male': '<=50K'}},
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Tech-support': '<=50K',
#       ' Transport-moving': {'marital-status': {' Divorced': {'workclass': {' Local-gov': '<=50K',
#           ' Private': {'sex': {' Female': '<=50K',
#             ' Male': {'race': {' White': '<=50K'}}}},
#           ' Self-emp-not-inc': '<=50K',
#           ' State-gov': '<=50K'}},
#         ' Never-married': '<=50K',
#         ' Separated': '<=50K',
#         ' Widowed': {'workclass': {' Private': '<=50K'}}}}}},
#     ' Masters': {'marital-status': {' Divorced': {'race': {' Asian-Pac-Islander': '<=50K',
#         ' Black': '>50K',
#         ' White': {'workclass': {' Local-gov': {'sex': {' Female': {'occupation': {' Prof-specialty': '<=50K'}},
#             ' Male': '<=50K'}},
#           ' Private': {'occupation': {' Exec-managerial': {'sex': {' Female': '<=50K',
#               ' Male': '<=50K'}},
#             ' Other-service': '<=50K',
#             ' Prof-specialty': {'sex': {' Female': '<=50K',
#               ' Male': '>50K'}}}},
#           ' Self-emp-inc': '>50K',
#           ' Self-emp-not-inc': {'occupation': {' Exec-managerial': '>50K',
#             ' Handlers-cleaners': '<=50K',
#             ' Prof-specialty': {'sex': {' Female': '<=50K', ' Male': '>50K'}},
#             ' Sales': '>50K'}},
#           ' State-gov': '<=50K'}}}},
#       ' Married-spouse-absent': '<=50K',
#       ' Never-married': {'workclass': {' Local-gov': {'occupation': {' Prof-specialty': '<=50K'}},
#         ' Private': '<=50K',
#         ' State-gov': '<=50K'}},
#       ' Separated': '<=50K',
#       ' Widowed': '<=50K'}},
#     ' Preschool': '<=50K',
#     ' Prof-school': {'workclass': {' Local-gov': '<=50K',
#       ' Private': '<=50K',
#       ' Self-emp-not-inc': '>50K',
#       ' State-gov': '<=50K'}},
#     ' Some-college': {'occupation': {' Adm-clerical': {'sex': {' Female': '<=50K',
#         ' Male': {'marital-status': {' Divorced': '<=50K',
#           ' Never-married': {'workclass': {' Private': '<=50K'}}}}}},
#       ' Craft-repair': {'marital-status': {' Divorced': '<=50K',
#         ' Never-married': '<=50K',
#         ' Separated': '>50K',
#         ' Widowed': '<=50K'}},
#       ' Exec-managerial': '<=50K',
#       ' Farming-fishing': {'marital-status': {' Divorced': {'workclass': {' Self-emp-not-inc': '<=50K'}},
#         ' Widowed': '<=50K'}},
#       ' Handlers-cleaners': '<=50K',
#       ' Machine-op-inspct': {'sex': {' Female': '<=50K',
#         ' Male': {'marital-status': {' Divorced': {'workclass': {' Private': '<=50K'}},
#           ' Never-married': '<=50K'}}}},
#       ' Other-service': '<=50K',
#       ' Prof-specialty': {'marital-status': {' Divorced': '<=50K',
#         ' Married-spouse-absent': '<=50K',
#         ' Never-married': {'workclass': {' Private': {'race': {' White': '<=50K'}},
#           ' Self-emp-not-inc': '<=50K'}}}},
#       ' Protective-serv': {'race': {' Amer-Indian-Eskimo': '>50K',
#         ' White': '<=50K'}},
#       ' Sales': {'marital-status': {' Divorced': '<=50K',
#         ' Never-married': '<=50K',
#         ' Separated': '<=50K',
#         ' Widowed': {'sex': {' Female': '<=50K', ' Male': '>50K'}}}},
#       ' Tech-support': {'sex': {' Female': '<=50K',
#         ' Male': {'workclass': {' Private': '>50K', ' State-gov': '<=50K'}}}},
#       ' Transport-moving': '<=50K'}}}},
#   ' Wife': {'occupation': {' Adm-clerical': {'workclass': {' Federal-gov': '>50K',
#       ' Local-gov': {'education': {' Assoc-acdm': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' Bachelors': '<=50K',
#         ' HS-grad': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' Some-college': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#       ' Private': {'native-country': {' Canada': '>50K',
#         ' Cuba': '>50K',
#         ' Germany': '>50K',
#         ' India': '<=50K',
#         ' Italy': '>50K',
#         ' Jamaica': '<=50K',
#         ' Laos': '<=50K',
#         ' Mexico': '<=50K',
#         ' United-States': {'education': {' 10th': '<=50K',
#           ' Assoc-acdm': {'race': {' Amer-Indian-Eskimo': '>50K',
#             ' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' White': '<=50K'}},
#           ' Assoc-voc': {'race': {' Black': '<=50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#           ' Bachelors': {'race': {' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' HS-grad': {'race': {' Black': '<=50K',
#             ' White': {'marital-status': {' Married-AF-spouse': '<=50K',
#               ' Married-civ-spouse': '<=50K'}}}},
#           ' Some-college': {'race': {' Amer-Indian-Eskimo': '<=50K',
#             ' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}}}}}},
#       ' Self-emp-inc': '>50K',
#       ' Self-emp-not-inc': {'education': {' Assoc-acdm': '>50K',
#         ' Bachelors': '<=50K',
#         ' HS-grad': '<=50K',
#         ' Some-college': '>50K'}},
#       ' State-gov': '<=50K'}},
#     ' Craft-repair': {'education': {' 10th': '<=50K',
#       ' 12th': '<=50K',
#       ' 5th-6th': '<=50K',
#       ' Assoc-acdm': '>50K',
#       ' Assoc-voc': '<=50K',
#       ' Bachelors': '<=50K',
#       ' HS-grad': {'race': {' Black': '<=50K',
#         ' White': {'workclass': {' Private': '<=50K'}}}},
#       ' Some-college': '<=50K'}},
#     ' Exec-managerial': {'native-country': {' Canada': '>50K',
#       ' Germany': '<=50K',
#       ' Iran': '>50K',
#       ' Mexico': '<=50K',
#       ' Philippines': '>50K',
#       ' Portugal': '>50K',
#       ' Puerto-Rico': '>50K',
#       ' South': '<=50K',
#       ' Taiwan': '<=50K',
#       ' Thailand': '>50K',
#       ' United-States': {'education': {' 9th': {'race': {' Asian-Pac-Islander': '>50K',
#           ' White': '<=50K'}},
#         ' Assoc-acdm': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Self-emp-inc': '>50K'}},
#         ' Assoc-voc': {'race': {' Black': '<=50K', ' White': '>50K'}},
#         ' Bachelors': {'workclass': {' Federal-gov': '<=50K',
#           ' Private': {'race': {' Black': '>50K',
#             ' White': {'marital-status': {' Married-AF-spouse': '>50K',
#               ' Married-civ-spouse': '>50K'}}}},
#           ' Self-emp-inc': '>50K',
#           ' State-gov': '>50K'}},
#         ' Doctorate': '>50K',
#         ' HS-grad': {'workclass': {' Local-gov': {'race': {' Black': '>50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#           ' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Self-emp-inc': '>50K',
#           ' State-gov': '>50K'}},
#         ' Masters': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Self-emp-not-inc': '>50K'}},
#         ' Prof-school': '>50K',
#         ' Some-college': {'workclass': {' Federal-gov': '>50K',
#           ' Local-gov': '>50K',
#           ' Private': {'race': {' Black': '>50K',
#             ' Other': '<=50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#           ' Self-emp-inc': '<=50K',
#           ' State-gov': '<=50K'}}}}}},
#     ' Farming-fishing': '<=50K',
#     ' Handlers-cleaners': {'education': {' 10th': '<=50K',
#       ' Bachelors': '>50K',
#       ' HS-grad': '>50K',
#       ' Some-college': '<=50K'}},
#     ' Machine-op-inspct': {'native-country': {' Canada': '>50K',
#       ' China': '<=50K',
#       ' Dominican-Republic': '<=50K',
#       ' Mexico': '<=50K',
#       ' Peru': '<=50K',
#       ' Portugal': '<=50K',
#       ' Puerto-Rico': '<=50K',
#       ' Thailand': '<=50K',
#       ' Trinadad&Tobago': '<=50K',
#       ' United-States': {'education': {' 10th': '<=50K',
#         ' 11th': '<=50K',
#         ' 7th-8th': '<=50K',
#         ' 9th': '>50K',
#         ' HS-grad': {'workclass': {' Private': {'race': {' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#           ' Self-emp-not-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Some-college': '>50K'}},
#       ' Vietnam': '>50K'}},
#     ' Other-service': {'education': {' 10th': '<=50K',
#       ' 11th': '<=50K',
#       ' 12th': '<=50K',
#       ' 1st-4th': '<=50K',
#       ' 9th': '<=50K',
#       ' Assoc-acdm': {'workclass': {' Local-gov': '<=50K',
#         ' Private': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' Self-emp-not-inc': '<=50K'}},
#       ' Assoc-voc': {'race': {' Amer-Indian-Eskimo': '<=50K',
#         ' Black': '<=50K',
#         ' White': '>50K'}},
#       ' Bachelors': {'native-country': {' Poland': '<=50K',
#         ' Puerto-Rico': '<=50K',
#         ' United-States': {'race': {' Asian-Pac-Islander': '>50K',
#           ' White': {'workclass': {' Private': '<=50K'}}}}}},
#       ' HS-grad': {'native-country': {' Italy': '<=50K',
#         ' Jamaica': '>50K',
#         ' Mexico': '<=50K',
#         ' Peru': '<=50K',
#         ' Philippines': '<=50K',
#         ' South': '<=50K',
#         ' United-States': {'workclass': {' Local-gov': '<=50K',
#           ' Private': {'race': {' Black': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#             ' White': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#           ' Self-emp-not-inc': '<=50K'}}}},
#       ' Some-college': {'workclass': {' Private': {'race': {' Amer-Indian-Eskimo': '<=50K',
#           ' Black': '<=50K',
#           ' White': {'native-country': {' Puerto-Rico': '<=50K',
#             ' United-States': {'marital-status': {' Married-civ-spouse': '<=50K'}}}}}},
#         ' Self-emp-not-inc': '<=50K',
#         ' State-gov': '<=50K'}}}},
#     ' Priv-house-serv': '<=50K',
#     ' Prof-specialty': {'native-country': {' Cuba': '<=50K',
#       ' Honduras': '>50K',
#       ' Iran': '>50K',
#       ' Italy': '>50K',
#       ' South': '<=50K',
#       ' United-States': {'workclass': {' Local-gov': {'race': {' Black': '>50K',
#           ' White': {'education': {' Bachelors': {'marital-status': {' Married-civ-spouse': '>50K'}},
#             ' Masters': {'marital-status': {' Married-civ-spouse': '>50K'}}}}}},
#         ' Private': {'education': {' Assoc-acdm': '>50K',
#           ' Assoc-voc': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#           ' Bachelors': {'race': {' Black': '>50K',
#             ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#           ' Doctorate': '<=50K',
#           ' HS-grad': '<=50K',
#           ' Masters': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Prof-school': '>50K',
#           ' Some-college': {'marital-status': {' Married-civ-spouse': '>50K'}}}},
#         ' Self-emp-inc': '>50K',
#         ' Self-emp-not-inc': {'education': {' Assoc-acdm': '>50K',
#           ' Bachelors': '>50K',
#           ' HS-grad': '>50K',
#           ' Prof-school': '<=50K',
#           ' Some-college': '>50K'}},
#         ' State-gov': '>50K'}}}},
#     ' Protective-serv': '<=50K',
#     ' Sales': {'education': {' Assoc-acdm': '>50K',
#       ' Assoc-voc': '>50K',
#       ' Bachelors': {'native-country': {' Puerto-Rico': '<=50K',
#         ' South': '<=50K',
#         ' United-States': {'workclass': {' Private': {'marital-status': {' Married-civ-spouse': '>50K'}},
#           ' Self-emp-inc': '>50K'}}}},
#       ' HS-grad': {'workclass': {' Federal-gov': '<=50K',
#         ' Private': {'native-country': {' Greece': '<=50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Self-emp-inc': {'marital-status': {' Married-civ-spouse': '<=50K'}},
#         ' Self-emp-not-inc': {'race': {' Black': '>50K',
#           ' White': {'marital-status': {' Married-civ-spouse': '>50K'}}}}}},
#       ' Masters': {'workclass': {' Private': '<=50K'}},
#       ' Prof-school': '>50K',
#       ' Some-college': {'workclass': {' Private': {'native-country': {' Germany': '<=50K',
#           ' United-States': {'marital-status': {' Married-civ-spouse': '<=50K'}}}},
#         ' Self-emp-inc': '<=50K',
#         ' Self-emp-not-inc': '<=50K'}}}},
#     ' Tech-support': {'education': {' 9th': '<=50K',
#       ' Assoc-voc': '>50K',
#       ' Bachelors': '>50K',
#       ' HS-grad': {'workclass': {' Private': '<=50K'}},
#       ' Some-college': {'race': {' Black': '<=50K', ' White': '>50K'}}}},
#     ' Transport-moving': {'education': {' 10th': '<=50K',
#       ' Assoc-acdm': '>50K',
#       ' Assoc-voc': '>50K',
#       ' HS-grad': '<=50K',
#       ' Some-college': {'workclass': {' Local-gov': '<=50K',
#         ' Self-emp-inc': '>50K'}}}}}}}}
